# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/messy_supermarket_530_rows.csv")

# %%
df
# Out:
#      Transaction_ID       Date     Store       City  Product Category  \
# 0              1141   1/5/2024    Imtiaz  ISLAMABAD  Chicken    Dairy
# 1              1399  4/11/2024    IMTIAZ  ISLAMABAD      Oil    DAIRY
# 2              1007  4/12/2024    IMTIAZ  ISLAMABAD      Oil   Bakery
# 3              1335   2/4/2024    IMTIAZ  Islamabad  Chicken   Fruits
# 4              1323  6/14/2024     metro  Islamabad     Milk   fruits
# ..              ...        ...       ...        ...      ...      ...
# 525            1072   7/5/2024    IMTIAZ     Lahore     Rice    DAIRY
# 526            1107   4/2/2024   Alfatah    Karachi    Apple    DAIRY
# 527            1271  10/6/2024    IMTIAZ    Karachi     Rice   fruits
# 528            1436   5/6/2024    IMTIAZ     Lahore    Apple   Grains
# 529            1103   8/5/2024  Al-Fatah    karachi      Oil     meat
#
#     Quantity Unit_Price  Total_Price Payment_Method Customer_Type
# 0        1kg        NaN          NaN         Online        member
# 1          5        NaN        546.0         Online       Regular
# 2        NaN     785/kg          NaN           CARD       regular
# 3          1     848/kg          NaN           Cash       Regular
# 4          1        NaN       1419.0           cash       Regular
# ..       ...        ...          ...            ...           ...
# 525      2kg     310/kg       2191.0           Card        Member
# 526      2kg        834       1955.0         Online       Regular
# 527        6        512       1481.0           Card        member
# 528        6        NaN          NaN           cash       Regular
# 529        1     970/kg        790.0         Online       regular
#
# [530 rows x 11 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.head()
# Out:
#    Transaction_ID       Date   Store       City  Product Category Quantity  \
# 0            1141   1/5/2024  Imtiaz  ISLAMABAD  Chicken    Dairy      1kg
# 1            1399  4/11/2024  IMTIAZ  ISLAMABAD      Oil    DAIRY        5
# 2            1007  4/12/2024  IMTIAZ  ISLAMABAD      Oil   Bakery      NaN
# 3            1335   2/4/2024  IMTIAZ  Islamabad  Chicken   Fruits        1
# 4            1323  6/14/2024   metro  Islamabad     Milk   fruits        1
#
#   Unit_Price  Total_Price Payment_Method Customer_Type
# 0        NaN          NaN         Online        member
# 1        NaN        546.0         Online       Regular
# 2     785/kg          NaN           CARD       regular
# 3     848/kg          NaN           Cash       Regular
# 4        NaN       1419.0           cash       Regular

# %%
df.dtypes
# Out:
# Transaction_ID      int64
# Date               object
# Store              object
# City               object
# Product            object
# Category           object
# Quantity           object
# Unit_Price         object
# Total_Price       float64
# Payment_Method     object
# Customer_Type      object
# dtype: object

# %%
df.shape
# Out:
# (530, 11)

# %%
print("total rows:", df.shape[0])
print("total columns:", df.shape[1])
# Out:
# total rows: 530
# total columns: 11

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# Date                0
# Store               0
# City                0
# Product             0
# Category            0
# Quantity          182
# Unit_Price        184
# Total_Price       255
# Payment_Method      0
# Customer_Type       0
# dtype: int64

# %%
df.nunique()
# Out:
# Transaction_ID    500
# Date              281
# Store               6
# City                6
# Product             8
# Category           10
# Quantity           15
# Unit_Price        308
# Total_Price       255
# Payment_Method      5
# Customer_Type       4
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(30)

# %%
df.describe()
# Out:
#        Transaction_ID  Total_Price
# count      530.000000   275.000000
# mean      1252.373585  2548.523636
# std        145.570529  1450.874373
# min       1001.000000   107.000000
# 25%       1125.000000  1254.500000
# 50%       1253.500000  2450.000000
# 75%       1378.000000  3839.000000
# max       1500.000000  4997.000000

# %%
df.count()
# Out:
# Transaction_ID    530
# Date              530
# Store             530
# City              530
# Product           530
# Category          530
# Quantity          348
# Unit_Price        346
# Total_Price       275
# Payment_Method    530
# Customer_Type     530
# dtype: int64

# %% [markdown]
# **## Data Preprocessing**

# %%
# remove duplicates values
df.duplicated().sum()
# Out:
# np.int64(30)

# %%
df=df.drop_duplicates(keep= 'first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (500, 11)

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Store', 'City', 'Product', 'Category',
#        'Quantity', 'Unit_Price', 'Total_Price', 'Payment_Method',
#        'Customer_Type'],
#       dtype='object')

# %%
df['Transaction_ID'].unique()
# Out:
# array([1141, 1399, 1007, 1335, 1323, 1083, 1226, 1497, 1357, 1102, 1011,
#        1078, 1300, 1319, 1470, 1003, 1159, 1258, 1195, 1317, 1447, 1105,
#        1149, 1336, 1181, 1091, 1196, 1228, 1074, 1056, 1378, 1347, 1031,
#        1076, 1341, 1071, 1010, 1223, 1185, 1457, 1290, 1205, 1281, 1239,
#        1302, 1133, 1080, 1462, 1168, 1477, 1090, 1366, 1269, 1448, 1186,
#        1472, 1358, 1219, 1496, 1348, 1288, 1073, 1409, 1155, 1118, 1069,
#        1298, 1064, 1403, 1210, 1077, 1183, 1034, 1079, 1085, 1001, 1012,
#        1023, 1272, 1235, 1362, 1474, 1368, 1193, 1019, 1421, 1407, 1016,
#        1238, 1040, 1485, 1047, 1094, 1173, 1435, 1463, 1342, 1432, 1132,
#        1339, 1372, 1138, 1498, 1418, 1070, 1371, 1313, 1370, 1376, 1174,
#        1332, 1411, 1125, 1156, 1440, 1363, 1150, 1369, 1087, 1312, 1349,
#        1285, 1465, 1361, 1415, 1020, 1057, 1374, 1401, 1356, 1454, 1325,
#        1026, 1439, 1043, 1354, 1154, 1178, 1297, 1127, 1438, 1032, 1114,
#        1230, 1322, 1441, 1058, 1221, 1025, 1018, 1204, 1067, 1450, 1256,
#        1333, 1177, 1095, 1489, 1232, 1024, 1279, 1229, 1006, 1117, 1046,
#        1197, 1311, 1017, 1499, 1384, 1004, 1250, 1211, 1061, 1111, 1343,
#        1030, 1212, 1445, 1027, 1008, 1182, 1487, 1109, 1038, 1158, 1375,
#        1119, 1115, 1278, 1176, 1385, 1209, 1145, 1397, 1299, 1246, 1249,
#        1479, 1142, 1393, 1068, 1471, 1169, 1189, 1248, 1404, 1484, 1194,
#        1082, 1110, 1146, 1093, 1153, 1287, 1423, 1262, 1383, 1084, 1104,
#        1166, 1164, 1200, 1305, 1075, 1461, 1245, 1395, 1120, 1416, 1483,
#        1273, 1381, 1430, 1405, 1495, 1266, 1473, 1412, 1291, 1251, 1389,
#        1037, 1140, 1254, 1437, 1060, 1112, 1282, 1275, 1263, 1452, 1151,
#        1267, 1424, 1039, 1337, 1199, 1276, 1147, 1422, 1148, 1478, 1306,
#        1124, 1396, 1097, 1144, 1240, 1292, 1098, 1425, 1377, 1123, 1184,
#        1203, 1247, 1326, 1321, 1426, 1303, 1126, 1324, 1224, 1449, 1220,
#        1130, 1451, 1308, 1353, 1406, 1488, 1382, 1295, 1394, 1365, 1113,
#        1180, 1330, 1486, 1355, 1315, 1152, 1387, 1234, 1481, 1334, 1165,
#        1318, 1137, 1198, 1259, 1233, 1116, 1121, 1225, 1433, 1128, 1491,
#        1286, 1466, 1442, 1108, 1398, 1350, 1134, 1391, 1045, 1066, 1284,
#        1086, 1243, 1187, 1413, 1160, 1013, 1036, 1029, 1171, 1143, 1429,
#        1427, 1222, 1096, 1052, 1241, 1400, 1352, 1408, 1179, 1042, 1469,
#        1417, 1207, 1283, 1359, 1255, 1443, 1005, 1257, 1482, 1101, 1227,
#        1458, 1214, 1453, 1172, 1099, 1293, 1216, 1062, 1048, 1033, 1268,
#        1328, 1201, 1480, 1028, 1419, 1231, 1261, 1379, 1289, 1163, 1392,
#        1456, 1139, 1063, 1136, 1129, 1009, 1327, 1500, 1065, 1301, 1015,
#        1157, 1041, 1380, 1494, 1434, 1217, 1410, 1280, 1468, 1493, 1338,
#        1237, 1208, 1213, 1296, 1252, 1492, 1304, 1351, 1270, 1202, 1162,
#        1044, 1218, 1402, 1191, 1310, 1260, 1106, 1054, 1390, 1002, 1360,
#        1050, 1420, 1081, 1206, 1035, 1431, 1264, 1428, 1455, 1367, 1092,
#        1340, 1053, 1346, 1265, 1242, 1014, 1316, 1089, 1388, 1274, 1167,
#        1329, 1135, 1307, 1320, 1244, 1055, 1364, 1051, 1490, 1175, 1446,
#        1190, 1464, 1188, 1476, 1170, 1059, 1475, 1049, 1345, 1236, 1253,
#        1022, 1314, 1460, 1161, 1277, 1444, 1192, 1386, 1294, 1414, 1344,
#        1309, 1131, 1100, 1373, 1088, 1459, 1331, 1215, 1467, 1122, 1021,
#        1072, 1107, 1271, 1436, 1103])

# %%
# Conversion of Multiple date formate like DD-MM-YY, MM,DD,YY ,Desh formate

df['Date'].unique()
# Out:
# array(['1/5/2024', '4/11/2024', '4/12/2024', '2/4/2024', '6/14/2024',
#        '2/29/2024', '7/1/2024', '20-04-2024', '1/3/2024', '14-03-2024',
#        '6/9/2024', '4/26/2024', '3/2/2024', '4/4/2024', '25-02-2024',
#        '3/28/2024', '4/2/2024', '1/6/2024', '25/04/2024', '6/3/2024',
#        '22/05/2024', '16/05/2024', '24/01/2024', '2/9/2024', '5/22/2024',
#        '27-04-2024', '9/5/2024', '6/28/2024', '19/03/2024', '3/8/2024',
#        '7/5/2024', '8/4/2024', '16-04-2024', '28-02-2024', '1/15/2024',
#        '23/06/2024', '10/1/2024', '27/03/2024', '28-06-2024', '11/3/2024',
#        '25-01-2024', '24-05-2024', '1/24/2024', '25-06-2024',
#        '29-01-2024', '18/02/2024', '3/16/2024', '6/19/2024', '14-06-2024',
#        '7/3/2024', '6/5/2024', '20/04/2024', '21-04-2024', '31-01-2024',
#        '16-01-2024', '5/30/2024', '16/04/2024', '16-06-2024', '8/1/2024',
#        '4/24/2024', '29-04-2024', '21-06-2024', '6/11/2024', '12/6/2024',
#        '19-03-2024', '30-03-2024', '4/13/2024', '16-02-2024',
#        '18-05-2024', '4/29/2024', '18/04/2024', '1/23/2024', '3/23/2024',
#        '18-02-2024', '26/02/2024', '4/17/2024', '3/10/2024', '25/02/2024',
#        '12/1/2024', '5/3/2024', '14/03/2024', '7/6/2024', '31/03/2024',
#        '23/02/2024', '19-06-2024', '6/1/2024', '26-01-2024', '4/25/2024',
#        '6/4/2024', '5/17/2024', '24/04/2024', '3/1/2024', '23-05-2024',
#        '16/01/2024', '13/05/2024', '25/05/2024', '17-02-2024', '7/4/2024',
#        '2/1/2024', '29/03/2024', '1/14/2024', '8/5/2024', '10/2/2024',
#        '28/01/2024', '23/03/2024', '4/3/2024', '13-02-2024', '20/01/2024',
#        '3/6/2024', '2/10/2024', '11/4/2024', '4/1/2024', '1/2/2024',
#        '4/5/2024', '18-06-2024', '18-03-2024', '31/01/2024', '14-01-2024',
#        '8/3/2024', '24-01-2024', '5/16/2024', '3/29/2024', '27-05-2024',
#        '6/2/2024', '14/05/2024', '1/25/2024', '30-01-2024', '5/20/2024',
#        '2/3/2024', '6/27/2024', '21/06/2024', '6/6/2024', '31-03-2024',
#        '29/01/2024', '1/30/2024', '13-03-2024', '14/01/2024',
#        '17-03-2024', '19-02-2024', '1/4/2024', '2/17/2024', '23/04/2024',
#        '1/1/2024', '2/6/2024', '4/7/2024', '22-04-2024', '3/17/2024',
#        '2/19/2024', '1/9/2024', '2/28/2024', '13/02/2024', '22-03-2024',
#        '27/06/2024', '12/3/2024', '21-05-2024', '15-03-2024', '4/6/2024',
#        '10/4/2024', '29-03-2024', '14/04/2024', '22/06/2024',
#        '22/04/2024', '6/25/2024', '27-03-2024', '27/02/2024',
#        '24/03/2024', '15/01/2024', '14-02-2024', '2/25/2024', '1/12/2024',
#        '3/21/2024', '28/04/2024', '18-04-2024', '26/06/2024', '11/5/2024',
#        '25-03-2024', '28/03/2024', '25-05-2024', '23-06-2024',
#        '15/04/2024', '27/04/2024', '27-02-2024', '1/20/2024',
#        '21-03-2024', '5/21/2024', '12/4/2024', '26-02-2024', '9/1/2024',
#        '3/9/2024', '3/31/2024', '5/25/2024', '6/20/2024', '23-04-2024',
#        '2/12/2024', '15-02-2024', '19/01/2024', '5/12/2024', '26/03/2024',
#        '1/7/2024', '11/2/2024', '8/2/2024', '11/1/2024', '3/14/2024',
#        '31/05/2024', '14/02/2024', '19/04/2024', '6/12/2024',
#        '14-04-2024', '17-05-2024', '5/10/2024', '20-01-2024', '5/19/2024',
#        '15/03/2024', '26/04/2024', '3/20/2024', '5/4/2024', '23-03-2024',
#        '26-03-2024', '5/15/2024', '6/18/2024', '26-04-2024', '1/21/2024',
#        '2/11/2024', '1/18/2024', '4/15/2024', '16/02/2024', '3/3/2024',
#        '17/03/2024', '26/05/2024', '1/19/2024', '14-05-2024',
#        '22/01/2024', '1/10/2024', '17/01/2024', '1/27/2024', '3/26/2024',
#        '29-02-2024', '13-04-2024', '14/06/2024', '5/2/2024', '17/02/2024',
#        '5/9/2024', '2/2/2024', '24-03-2024', '6/17/2024', '13-01-2024',
#        '5/27/2024', '1/16/2024', '1/26/2024', '21/03/2024', '1/8/2024',
#        '9/6/2024', '30-05-2024', '18/05/2024', '28-03-2024', '15-04-2024',
#        '26/01/2024', '21/01/2024', '10/5/2024', '4/30/2024', '29/02/2024',
#        '5/5/2024', '3/30/2024', '28/05/2024', '5/1/2024', '13/03/2024',
#        '6/10/2024', '12/2/2024', '2/20/2024', '25/06/2024', '17/06/2024',
#        '17-04-2024', '2/23/2024', '23-01-2024', '3/4/2024', '28/06/2024',
#        '21/05/2024', '4/10/2024', '24-04-2024', '10/6/2024', '5/6/2024'],
#       dtype=object)

# %%
pd.to_datetime(df['Date'], format="mixed")
# Out:
# 0     2024-01-05
# 1     2024-04-11
# 2     2024-04-12
# 3     2024-02-04
# 4     2024-06-14
#          ...
# 525   2024-07-05
# 526   2024-04-02
# 527   2024-10-06
# 528   2024-05-06
# 529   2024-08-05
# Name: Date, Length: 500, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 0 to 529
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  500 non-null    int64
#  1   Date            500 non-null    object
#  2   Store           500 non-null    object
#  3   City            500 non-null    object
#  4   Product         500 non-null    object
#  5   Category        500 non-null    object
#  6   Quantity        327 non-null    object
#  7   Unit_Price      328 non-null    object
#  8   Total_Price     263 non-null    float64
#  9   Payment_Method  500 non-null    object
#  10  Customer_Type   500 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 46.9+ KB

# %%
pd.to_datetime(df['Date'], format="mixed")
# Out:
# 0     2024-01-05
# 1     2024-04-11
# 2     2024-04-12
# 3     2024-02-04
# 4     2024-06-14
#          ...
# 525   2024-07-05
# 526   2024-04-02
# 527   2024-10-06
# 528   2024-05-06
# 529   2024-08-05
# Name: Date, Length: 500, dtype: datetime64[ns]

# %%
df['Date']=pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')

# %%
df["Date"].isnull().sum()
# Out:
# np.int64(203)

# %%
df["Date"] = df["Date"].fillna(method ='ffill')

# %%
df['Date'].unique()
# Out:
# <DatetimeArray>
# ['2024-05-01 00:00:00', '2024-11-04 00:00:00', '2024-12-04 00:00:00',
#  '2024-04-02 00:00:00', '2024-01-07 00:00:00', '2024-03-01 00:00:00',
#  '2024-09-06 00:00:00', '2024-02-03 00:00:00', '2024-04-04 00:00:00',
#  '2024-02-04 00:00:00',
#  ...
#  '2024-10-06 00:00:00', '2024-02-12 00:00:00', '2024-06-25 00:00:00',
#  '2024-06-17 00:00:00', '2024-04-03 00:00:00', '2024-06-28 00:00:00',
#  '2024-05-21 00:00:00', '2024-10-04 00:00:00', '2024-06-10 00:00:00',
#  '2024-06-05 00:00:00']
# Length: 153, dtype: datetime64[ns]

# %%
df["Date"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Convert standardize case, fix spelling / formatting,

df['Store'].unique()
# Out:
# array(['Imtiaz', 'IMTIAZ', 'metro', 'Alfatah', 'Metro', 'Al-Fatah'],
#       dtype=object)

# %%
df['Store']= df["Store"].str.title()
df['Store']= df["Store"].replace({'Al-Fatah':'Alfatah'})

# %%
df['Store'].unique()
# Out:
# array(['Imtiaz', 'Metro', 'Alfatah'], dtype=object)

# %%
df
# Out:
#      Transaction_ID       Date    Store       City  Product Category Quantity  \
# 0              1141 2024-05-01   Imtiaz  ISLAMABAD  Chicken    Dairy      1kg
# 1              1399 2024-11-04   Imtiaz  ISLAMABAD      Oil    DAIRY        5
# 2              1007 2024-12-04   Imtiaz  ISLAMABAD      Oil   Bakery      NaN
# 3              1335 2024-04-02   Imtiaz  Islamabad  Chicken   Fruits        1
# 4              1323 2024-04-02    Metro  Islamabad     Milk   fruits        1
# ..              ...        ...      ...        ...      ...      ...      ...
# 525            1072 2024-05-07   Imtiaz     Lahore     Rice    DAIRY      2kg
# 526            1107 2024-02-04  Alfatah    Karachi    Apple    DAIRY      2kg
# 527            1271 2024-06-10   Imtiaz    Karachi     Rice   fruits        6
# 528            1436 2024-06-05   Imtiaz     Lahore    Apple   Grains        6
# 529            1103 2024-05-08  Alfatah    karachi      Oil     meat        1
#
#     Unit_Price  Total_Price Payment_Method Customer_Type
# 0          NaN          NaN         Online        member
# 1          NaN        546.0         Online       Regular
# 2       785/kg          NaN           CARD       regular
# 3       848/kg          NaN           Cash       Regular
# 4          NaN       1419.0           cash       Regular
# ..         ...          ...            ...           ...
# 525     310/kg       2191.0           Card        Member
# 526        834       1955.0         Online       Regular
# 527        512       1481.0           Card        member
# 528        NaN          NaN           cash       Regular
# 529     970/kg        790.0         Online       regular
#
# [500 rows x 11 columns]

# %%
# formate city name
# lower case / upper case issue

df['City'].unique()
# Out:
# array(['ISLAMABAD', 'Islamabad', 'Karachi', 'lahore', 'Lahore', 'karachi'],
#       dtype=object)

# %%
df['City']= df['City'].str.title()

# %%
df['City'].unique()
# Out:
# array(['Islamabad', 'Karachi', 'Lahore'], dtype=object)

# %%
# formate product name
# no error found

df['Product'].unique()
# Out:
# array(['Chicken', 'Oil', 'Milk', 'Apple', 'Sugar', 'Eggs', 'Rice',
#        'Bread'], dtype=object)

# %%
# formate catagory name
#lower / uppercase issue
# check extra space
# check spelling issue

df['Category'].unique()
# Out:
# array(['Dairy', 'DAIRY', 'Bakery', 'Fruits', 'fruits', 'Meat', 'grains',
#        'Grains', 'bakery', 'meat'], dtype=object)

# %%
df['Category']= df['Category'].str.strip()

# %%
df['Category']= df['Category'].str.title()

# %%
df['Category'].unique()
# Out:
# array(['Dairy', 'Bakery', 'Fruits', 'Meat', 'Grains'], dtype=object)

# %%
# formate Quantity
# check extra space
# replace 1kg into ""
# remove kg


df['Quantity'].unique()
# Out:
# array(['1kg', '5', nan, '1', '3', '4', '9', '5kg', '10', '6', '2kg',
#        '3kg', '7', '2', '4kg', '8'], dtype=object)

# %%
# replace kg into ''
# fill nan values

df['Quantity'].unique()
# Out:
# array(['1kg', '5', nan, '1', '3', '4', '9', '5kg', '10', '6', '2kg',
#        '3kg', '7', '2', '4kg', '8'], dtype=object)

# %%
df['Quantity'] = df['Quantity'].str.replace('kg', '')

# %%
df['Quantity'].unique()
# Out:
# array(['1', '5', nan, '3', '4', '9', '10', '6', '2', '7', '8'],
#       dtype=object)

# %%
pd.to_numeric(df['Quantity'])
# Out:
# 0      1.0
# 1      5.0
# 2      NaN
# 3      1.0
# 4      1.0
#       ...
# 525    2.0
# 526    2.0
# 527    6.0
# 528    6.0
# 529    1.0
# Name: Quantity, Length: 500, dtype: float64

# %%
df['Quantity'] =pd.to_numeric(df['Quantity'])

# %%
df['Quantity'] = df['Quantity'].fillna(df['Quantity'].median())

# %%
df['Quantity'].unique()
# Out:
# array([ 1.,  5.,  4.,  3.,  9., 10.,  6.,  2.,  7.,  8.])

# %%
# formate the price
#removing kg into ''
# removing "/"
# Fill nan values
df['Unit_Price'].unique()
# Out:
# array([nan, '785/kg', '848/kg', '333', '909', '443/kg', '206', '703/kg',
#        '860/kg', '713', '144/kg', '940/kg', '771', '447/kg', '953',
#        '405/kg', '419', '876/kg', '113/kg', '807', '880/kg', '854/kg',
#        '775', '209', '350', '518', '778/kg', '224/kg', '229', '389/kg',
#        '545', '810', '213', '480/kg', '369', '288/kg', '603/kg', '639',
#        '282', '915', '871', '256', '811/kg', '147', '740/kg', '223',
#        '193', '88', '540', '120', '118', '244', '913', '470/kg', '487/kg',
#        '962/kg', '474/kg', '526', '211', '123', '902', '870', '260',
#        '247/kg', '142/kg', '585', '508', '740', '460/kg', '119/kg', '599',
#        '726/kg', '369/kg', '669/kg', '963', '232/kg', '763', '512/kg',
#        '132', '531/kg', '773/kg', '863', '507', '817', '415/kg', '704/kg',
#        '630/kg', '852/kg', '468/kg', '524/kg', '167', '573/kg', '53',
#        '268/kg', '770/kg', '516', '402/kg', '277', '97', '454', '62',
#        '338', '290', '824', '92/kg', '136', '335/kg', '567', '245/kg',
#        '956/kg', '185/kg', '391/kg', '977', '564/kg', '743', '623/kg',
#        '648/kg', '574', '294/kg', '483/kg', '382/kg', '932', '254/kg',
#        '720/kg', '802/kg', '126', '125/kg', '664/kg', '411/kg', '891',
#        '238/kg', '942/kg', '575/kg', '469', '287/kg', '855/kg', '790',
#        '549', '78', '321', '298', '950', '504/kg', '691', '90/kg',
#        '952/kg', '244/kg', '461', '799/kg', '890/kg', '757/kg', '988/kg',
#        '825', '907/kg', '823/kg', '216/kg', '694/kg', '133', '449', '442',
#        '351', '104/kg', '168/kg', '718/kg', '125', '398', '849', '299',
#        '420/kg', '221/kg', '56', '728', '948/kg', '968', '614/kg', '697',
#        '358', '318', '617/kg', '611/kg', '430', '680', '309/kg', '872/kg',
#        '929', '735', '226/kg', '600/kg', '442/kg', '985/kg', '504',
#        '449/kg', '216', '337', '744/kg', '435', '455', '696', '297',
#        '323', '720', '981', '704', '278', '386', '395/kg', '676/kg',
#        '987', '571', '806/kg', '359/kg', '381/kg', '767', '101/kg', '54',
#        '266/kg', '744', '682/kg', '989', '904/kg', '760', '107/kg', '336',
#        '428', '977/kg', '304/kg', '831/kg', '841/kg', '922', '50/kg',
#        '971/kg', '543/kg', '810/kg', '179/kg', '856', '576', '707', '827',
#        '905', '562', '502', '493', '482', '764', '475/kg', '375',
#        '448/kg', '697/kg', '563/kg', '320', '494', '754/kg', '78/kg',
#        '906/kg', '753', '818', '585/kg', '838/kg', '777/kg', '738', '534',
#        '754', '137', '247', '708/kg', '308/kg', '690', '552/kg', '603',
#        '752/kg', '920', '266', '622/kg', '235', '926/kg', '959', '944',
#        '788/kg', '448', '719/kg', '61', '621/kg', '698/kg', '613/kg',
#        '333/kg', '383', '739', '128', '66/kg', '589', '314/kg', '767/kg',
#        '546/kg', '819', '901', '73/kg', '272', '597', '197/kg', '147/kg',
#        '57', '618/kg', '445', '925', '331', '310/kg', '834', '512',
#        '970/kg'], dtype=object)

# %%
df['Unit_Price']=df['Unit_Price'].str.replace('kg', '')
df['Unit_Price']=df['Unit_Price'].str.replace('/', '')
df['Unit_Price']=df['Unit_Price'].str.strip()
pd.to_numeric(df['Unit_Price'])
# Out:
# 0        NaN
# 1        NaN
# 2      785.0
# 3      848.0
# 4        NaN
#        ...
# 525    310.0
# 526    834.0
# 527    512.0
# 528      NaN
# 529    970.0
# Name: Unit_Price, Length: 500, dtype: float64

# %%
df['Unit_Price']=pd.to_numeric(df['Unit_Price'])

# %%
df['Unit_Price'].unique()
# Out:
# array([ nan, 785., 848., 333., 909., 443., 206., 703., 860., 713., 144.,
#        940., 771., 447., 953., 405., 419., 876., 113., 807., 880., 854.,
#        775., 209., 350., 518., 778., 224., 229., 389., 545., 810., 213.,
#        480., 369., 288., 603., 639., 282., 915., 871., 256., 811., 147.,
#        740., 223., 193.,  88., 540., 120., 118., 244., 913., 470., 487.,
#        962., 474., 526., 211., 123., 902., 870., 260., 247., 142., 585.,
#        508., 460., 119., 599., 726., 669., 963., 232., 763., 512., 132.,
#        531., 773., 863., 507., 817., 415., 704., 630., 852., 468., 524.,
#        167., 573.,  53., 268., 770., 516., 402., 277.,  97., 454.,  62.,
#        338., 290., 824.,  92., 136., 335., 567., 245., 956., 185., 391.,
#        977., 564., 743., 623., 648., 574., 294., 483., 382., 932., 254.,
#        720., 802., 126., 125., 664., 411., 891., 238., 942., 575., 469.,
#        287., 855., 790., 549.,  78., 321., 298., 950., 504., 691.,  90.,
#        952., 461., 799., 890., 757., 988., 825., 907., 823., 216., 694.,
#        133., 449., 442., 351., 104., 168., 718., 398., 849., 299., 420.,
#        221.,  56., 728., 948., 968., 614., 697., 358., 318., 617., 611.,
#        430., 680., 309., 872., 929., 735., 226., 600., 985., 337., 744.,
#        435., 455., 696., 297., 323., 981., 278., 386., 395., 676., 987.,
#        571., 806., 359., 381., 767., 101.,  54., 266., 682., 989., 904.,
#        760., 107., 336., 428., 304., 831., 841., 922.,  50., 971., 543.,
#        179., 856., 576., 707., 827., 905., 562., 502., 493., 482., 764.,
#        475., 375., 448., 563., 320., 494., 754., 906., 753., 818., 838.,
#        777., 738., 534., 137., 708., 308., 690., 552., 752., 920., 622.,
#        235., 926., 959., 944., 788., 719.,  61., 621., 698., 613., 383.,
#        739., 128.,  66., 589., 314., 546., 819., 901.,  73., 272., 597.,
#        197.,  57., 618., 445., 925., 331., 310., 834., 970.])

# %%
df['Unit_Price']= df['Unit_Price'].fillna(df['Unit_Price'].median())
df
# Out:
#      Transaction_ID       Date    Store       City  Product Category  \
# 0              1141 2024-05-01   Imtiaz  Islamabad  Chicken    Dairy
# 1              1399 2024-11-04   Imtiaz  Islamabad      Oil    Dairy
# 2              1007 2024-12-04   Imtiaz  Islamabad      Oil   Bakery
# 3              1335 2024-04-02   Imtiaz  Islamabad  Chicken   Fruits
# 4              1323 2024-04-02    Metro  Islamabad     Milk   Fruits
# ..              ...        ...      ...        ...      ...      ...
# 525            1072 2024-05-07   Imtiaz     Lahore     Rice    Dairy
# 526            1107 2024-02-04  Alfatah    Karachi    Apple    Dairy
# 527            1271 2024-06-10   Imtiaz    Karachi     Rice   Fruits
# 528            1436 2024-06-05   Imtiaz     Lahore    Apple   Grains
# 529            1103 2024-05-08  Alfatah    Karachi      Oil     Meat
#
#      Quantity  Unit_Price  Total_Price Payment_Method Customer_Type
# 0         1.0       537.0          NaN         Online        member
# 1         5.0       537.0        546.0         Online       Regular
# 2         4.0       785.0          NaN           CARD       regular
# 3         1.0       848.0          NaN           Cash       Regular
# 4         1.0       537.0       1419.0           cash       Regular
# ..        ...         ...          ...            ...           ...
# 525       2.0       310.0       2191.0           Card        Member
# 526       2.0       834.0       1955.0         Online       Regular
# 527       6.0       512.0       1481.0           Card        member
# 528       6.0       537.0          NaN           cash       Regular
# 529       1.0       970.0        790.0         Online       regular
#
# [500 rows x 11 columns]

# %%
df['Unit_Price'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Fill null values
df['Total_Price'].unique()
# Out:
# array([  nan,  546., 1419., 2844., 4959., 3160., 4854., 4518.,  987.,
#        1368., 3177.,  904., 2380.,  186., 1953., 4695., 1170., 4359.,
#        1082., 3475., 3816., 2595., 3452.,  839., 2504., 2886., 3498.,
#        4834., 4880., 1889., 1538., 1819., 2127., 3356., 2173., 4006.,
#        4683.,  939., 4081., 2578., 3156., 1042.,  579.,  543., 1865.,
#        4387., 4073., 2453., 2391.,  906.,  458.,  976., 4610., 1470.,
#        1399.,  912., 2021., 4510.,  195., 3159., 2805.,  661.,  367.,
#        3598., 3073., 4626., 2240., 2966., 3110., 2164., 3844., 4462.,
#        2245.,  580.,  674., 2396.,  162., 3971., 2908.,  829.,  992.,
#        4662., 2665., 2146.,  911., 2922., 4829.,  680.,  956., 3683.,
#        3325., 4445., 1876., 1366.,  315., 3178., 3942., 3703.,  622.,
#        3512., 4385., 1503.,  802., 2151., 4309., 1735., 3834.,  358.,
#        1292., 2819., 3903., 3917., 3526.,  885.,  153., 1611., 2095.,
#        2148., 2757.,  245., 3993., 1434., 4394., 3548., 4997., 3711.,
#        3064., 3163., 2284., 3750., 4677.,  391., 4923., 4722., 3851.,
#        4836., 2307., 1484.,  169., 1852., 1948., 4011., 2163., 2383.,
#        1761., 2750., 4839., 3380., 4288., 4746., 3607., 3656., 2097.,
#         107., 2301., 4788., 2250., 2286., 2137., 3213., 2464., 4512.,
#        1858., 2442., 2074., 4141.,  704., 4443., 1581., 3231., 4399.,
#        4164., 3090., 2684.,  610., 4873.,  200., 1217.,  304., 1825.,
#        4433., 4968., 3877., 4256., 3693., 2434.,  497., 2976.,  697.,
#        4315., 2450.,  831., 2971., 4603., 3233.,  350., 1757.,  971.,
#         418., 2990., 1117., 4517., 3701., 3968., 1606., 4719., 3412.,
#        1911.,  917., 4947., 2006.,  233.,  810.,  729., 3848., 2104.,
#        4720., 1329., 2916.,  572., 1146., 1034.,  167.,  241., 1165.,
#        3990., 3353.,  475., 2493., 1706., 2512., 1985., 3050., 4913.,
#         158., 1655., 4481., 3092., 2144., 4983., 2758., 2092., 2580.,
#        2360., 3854.,  408., 1024., 4402., 1812., 2227.,  437., 4192.,
#        2191., 1955., 1481.,  790.])

# %%
df['Total_Price']=df['Total_Price'].fillna(df['Total_Price'].median())

# %%
df['Total_Price'].isnull().sum()
# Out:
# np.int64(0)

# %%
# change case type
df['Payment_Method'].unique()
# Out:
# array(['Online', 'CARD', 'Cash', 'cash', 'Card'], dtype=object)

# %%
df['Payment_Method']=df['Payment_Method'].str.title()
df['Payment_Method'].unique()
# Out:
# array(['Online', 'Card', 'Cash'], dtype=object)

# %%
df['Payment_Method'].unique()
# Out:
# array(['Online', 'Card', 'Cash'], dtype=object)

# %%
# Replace 'Payment_Method' with actual column name
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# Cash      212
# Card      206
# Online     82
# Name: count, dtype: int64

# %%
df['Customer_Type'].unique()
# Out:
# array(['member', 'Regular', 'regular', 'Member'], dtype=object)

# %%
df['Customer_Type']=df['Customer_Type'].str.title()

# %%
df['Customer_Type'].unique()
# Out:
# array(['Member', 'Regular'], dtype=object)

# %%
# Now we can see all data has been cleaned and ready for "transformation"
df
# Out:
#      Transaction_ID       Date    Store       City  Product Category  \
# 0              1141 2024-05-01   Imtiaz  Islamabad  Chicken    Dairy
# 1              1399 2024-11-04   Imtiaz  Islamabad      Oil    Dairy
# 2              1007 2024-12-04   Imtiaz  Islamabad      Oil   Bakery
# 3              1335 2024-04-02   Imtiaz  Islamabad  Chicken   Fruits
# 4              1323 2024-04-02    Metro  Islamabad     Milk   Fruits
# ..              ...        ...      ...        ...      ...      ...
# 525            1072 2024-05-07   Imtiaz     Lahore     Rice    Dairy
# 526            1107 2024-02-04  Alfatah    Karachi    Apple    Dairy
# 527            1271 2024-06-10   Imtiaz    Karachi     Rice   Fruits
# 528            1436 2024-06-05   Imtiaz     Lahore    Apple   Grains
# 529            1103 2024-05-08  Alfatah    Karachi      Oil     Meat
#
#      Quantity  Unit_Price  Total_Price Payment_Method Customer_Type
# 0         1.0       537.0       2434.0         Online        Member
# 1         5.0       537.0        546.0         Online       Regular
# 2         4.0       785.0       2434.0           Card       Regular
# 3         1.0       848.0       2434.0           Cash       Regular
# 4         1.0       537.0       1419.0           Cash       Regular
# ..        ...         ...          ...            ...           ...
# 525       2.0       310.0       2191.0           Card        Member
# 526       2.0       834.0       1955.0         Online       Regular
# 527       6.0       512.0       1481.0           Card        Member
# 528       6.0       537.0       2434.0           Cash       Regular
# 529       1.0       970.0        790.0         Online       Regular
#
# [500 rows x 11 columns]

# %%
#  Wrong Category Mapping (Logical Error) between "product" and "catagor"

df['Product'].unique()
# Out:
# array(['Chicken', 'Oil', 'Milk', 'Apple', 'Sugar', 'Eggs', 'Rice',
#        'Bread'], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Dairy', 'Bakery', 'Fruits', 'Meat', 'Grains'], dtype=object)

# %%
# maping
cat_map = ({'Chicken': 'Meat',
           'Oil': 'Grains',
           'Milk': 'Dairy',
          'Apple': 'Fruits',
           'Sugar': 'Grains',
           'Eggs': 'Bakery',
           'Rice':'Grains',
           'Bread': 'Bakery'})

df['category']= df['Product'].map(cat_map)

# %%
df
# Out:
#      Transaction_ID       Date    Store       City  Product Category  \
# 0              1141 2024-05-01   Imtiaz  Islamabad  Chicken    Dairy
# 1              1399 2024-11-04   Imtiaz  Islamabad      Oil    Dairy
# 2              1007 2024-12-04   Imtiaz  Islamabad      Oil   Bakery
# 3              1335 2024-04-02   Imtiaz  Islamabad  Chicken   Fruits
# 4              1323 2024-04-02    Metro  Islamabad     Milk   Fruits
# ..              ...        ...      ...        ...      ...      ...
# 525            1072 2024-05-07   Imtiaz     Lahore     Rice    Dairy
# 526            1107 2024-02-04  Alfatah    Karachi    Apple    Dairy
# 527            1271 2024-06-10   Imtiaz    Karachi     Rice   Fruits
# 528            1436 2024-06-05   Imtiaz     Lahore    Apple   Grains
# 529            1103 2024-05-08  Alfatah    Karachi      Oil     Meat
#
#      Quantity  Unit_Price  Total_Price Payment_Method Customer_Type category
# 0         1.0       537.0       2434.0         Online        Member     Meat
# 1         5.0       537.0        546.0         Online       Regular   Grains
# 2         4.0       785.0       2434.0           Card       Regular   Grains
# 3         1.0       848.0       2434.0           Cash       Regular     Meat
# 4         1.0       537.0       1419.0           Cash       Regular    Dairy
# ..        ...         ...          ...            ...           ...      ...
# 525       2.0       310.0       2191.0           Card        Member   Grains
# 526       2.0       834.0       1955.0         Online       Regular   Fruits
# 527       6.0       512.0       1481.0           Card        Member   Grains
# 528       6.0       537.0       2434.0           Cash       Regular   Fruits
# 529       1.0       970.0        790.0         Online       Regular   Grains
#
# [500 rows x 12 columns]

# %%
# Now we have 02 columns with the same name, To remove column "catagery" because of wrong Mapping


df= df.drop(columns=['Category'])

# %%
df
# Out:
#      Transaction_ID       Date    Store       City  Product  Quantity  \
# 0              1141 2024-05-01   Imtiaz  Islamabad  Chicken       1.0
# 1              1399 2024-11-04   Imtiaz  Islamabad      Oil       5.0
# 2              1007 2024-12-04   Imtiaz  Islamabad      Oil       4.0
# 3              1335 2024-04-02   Imtiaz  Islamabad  Chicken       1.0
# 4              1323 2024-04-02    Metro  Islamabad     Milk       1.0
# ..              ...        ...      ...        ...      ...       ...
# 525            1072 2024-05-07   Imtiaz     Lahore     Rice       2.0
# 526            1107 2024-02-04  Alfatah    Karachi    Apple       2.0
# 527            1271 2024-06-10   Imtiaz    Karachi     Rice       6.0
# 528            1436 2024-06-05   Imtiaz     Lahore    Apple       6.0
# 529            1103 2024-05-08  Alfatah    Karachi      Oil       1.0
#
#      Unit_Price  Total_Price Payment_Method Customer_Type category
# 0         537.0       2434.0         Online        Member     Meat
# 1         537.0        546.0         Online       Regular   Grains
# 2         785.0       2434.0           Card       Regular   Grains
# 3         848.0       2434.0           Cash       Regular     Meat
# 4         537.0       1419.0           Cash       Regular    Dairy
# ..          ...          ...            ...           ...      ...
# 525       310.0       2191.0           Card        Member   Grains
# 526       834.0       1955.0         Online       Regular   Fruits
# 527       512.0       1481.0           Card        Member   Grains
# 528       537.0       2434.0           Cash       Regular   Fruits
# 529       970.0        790.0         Online       Regular   Grains
#
# [500 rows x 11 columns]

# %%
# total_ pirce Descrepencies (total amount is differ)

df['Total_Price']= df['Quantity']*df['Unit_Price']

df
# Out:
#      Transaction_ID       Date    Store       City  Product  Quantity  \
# 0              1141 2024-05-01   Imtiaz  Islamabad  Chicken       1.0
# 1              1399 2024-11-04   Imtiaz  Islamabad      Oil       5.0
# 2              1007 2024-12-04   Imtiaz  Islamabad      Oil       4.0
# 3              1335 2024-04-02   Imtiaz  Islamabad  Chicken       1.0
# 4              1323 2024-04-02    Metro  Islamabad     Milk       1.0
# ..              ...        ...      ...        ...      ...       ...
# 525            1072 2024-05-07   Imtiaz     Lahore     Rice       2.0
# 526            1107 2024-02-04  Alfatah    Karachi    Apple       2.0
# 527            1271 2024-06-10   Imtiaz    Karachi     Rice       6.0
# 528            1436 2024-06-05   Imtiaz     Lahore    Apple       6.0
# 529            1103 2024-05-08  Alfatah    Karachi      Oil       1.0
#
#      Unit_Price  Total_Price Payment_Method Customer_Type category
# 0         537.0        537.0         Online        Member     Meat
# 1         537.0       2685.0         Online       Regular   Grains
# 2         785.0       3140.0           Card       Regular   Grains
# 3         848.0        848.0           Cash       Regular     Meat
# 4         537.0        537.0           Cash       Regular    Dairy
# ..          ...          ...            ...           ...      ...
# 525       310.0        620.0           Card        Member   Grains
# 526       834.0       1668.0         Online       Regular   Fruits
# 527       512.0       3072.0           Card        Member   Grains
# 528       537.0       3222.0           Cash       Regular   Fruits
# 529       970.0        970.0         Online       Regular   Grains
#
# [500 rows x 11 columns]

# %%
# Re-arrange columns to
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Store', 'City', 'Product', 'Quantity',
#        'Unit_Price', 'Total_Price', 'Payment_Method', 'Customer_Type',
#        'category'],
#       dtype='object')

# %%
#
order_columns = ['Transaction_ID', 'Date', 'Store', 'City', 'Product','category', 'Quantity',
       'Unit_Price', 'Total_Price', 'Payment_Method', 'Customer_Type']


# Overwrite df and reset inex
df = df[order_columns].reset_index(drop =True)

# %%
# Data set has been cleaned, structured,in order form now,and ready for "Transformation"

df
# Out:
#      Transaction_ID       Date    Store       City  Product category  \
# 0              1141 2024-05-01   Imtiaz  Islamabad  Chicken     Meat
# 1              1399 2024-11-04   Imtiaz  Islamabad      Oil   Grains
# 2              1007 2024-12-04   Imtiaz  Islamabad      Oil   Grains
# 3              1335 2024-04-02   Imtiaz  Islamabad  Chicken     Meat
# 4              1323 2024-04-02    Metro  Islamabad     Milk    Dairy
# ..              ...        ...      ...        ...      ...      ...
# 495            1072 2024-05-07   Imtiaz     Lahore     Rice   Grains
# 496            1107 2024-02-04  Alfatah    Karachi    Apple   Fruits
# 497            1271 2024-06-10   Imtiaz    Karachi     Rice   Grains
# 498            1436 2024-06-05   Imtiaz     Lahore    Apple   Fruits
# 499            1103 2024-05-08  Alfatah    Karachi      Oil   Grains
#
#      Quantity  Unit_Price  Total_Price Payment_Method Customer_Type
# 0         1.0       537.0        537.0         Online        Member
# 1         5.0       537.0       2685.0         Online       Regular
# 2         4.0       785.0       3140.0           Card       Regular
# 3         1.0       848.0        848.0           Cash       Regular
# 4         1.0       537.0        537.0           Cash       Regular
# ..        ...         ...          ...            ...           ...
# 495       2.0       310.0        620.0           Card        Member
# 496       2.0       834.0       1668.0         Online       Regular
# 497       6.0       512.0       3072.0           Card        Member
# 498       6.0       537.0       3222.0           Cash       Regular
# 499       1.0       970.0        970.0         Online       Regular
#
# [500 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Transaction_ID    0
# Date              0
# Store             0
# City              0
# Product           0
# category          0
# Quantity          0
# Unit_Price        0
# Total_Price       0
# Payment_Method    0
# Customer_Type     0
# dtype: int64

# %%
df.dtypes
# Out:
# Transaction_ID             int64
# Date              datetime64[ns]
# Store                     object
# City                      object
# Product                   object
# category                  object
# Quantity                 float64
# Unit_Price               float64
# Total_Price              float64
# Payment_Method            object
# Customer_Type             object
# dtype: object

# %% [markdown]
# ## Extract "Month" from "Date"

# %%
df['Month']= df['Date'].dt.month_name()

# %%
df
# Out:
#      Transaction_ID       Date    Store       City  Product category  \
# 0              1141 2024-05-01   Imtiaz  Islamabad  Chicken     Meat
# 1              1399 2024-11-04   Imtiaz  Islamabad      Oil   Grains
# 2              1007 2024-12-04   Imtiaz  Islamabad      Oil   Grains
# 3              1335 2024-04-02   Imtiaz  Islamabad  Chicken     Meat
# 4              1323 2024-04-02    Metro  Islamabad     Milk    Dairy
# ..              ...        ...      ...        ...      ...      ...
# 495            1072 2024-05-07   Imtiaz     Lahore     Rice   Grains
# 496            1107 2024-02-04  Alfatah    Karachi    Apple   Fruits
# 497            1271 2024-06-10   Imtiaz    Karachi     Rice   Grains
# 498            1436 2024-06-05   Imtiaz     Lahore    Apple   Fruits
# 499            1103 2024-05-08  Alfatah    Karachi      Oil   Grains
#
#      Quantity  Unit_Price  Total_Price Payment_Method Customer_Type     Month
# 0         1.0       537.0        537.0         Online        Member       May
# 1         5.0       537.0       2685.0         Online       Regular  November
# 2         4.0       785.0       3140.0           Card       Regular  December
# 3         1.0       848.0        848.0           Cash       Regular     April
# 4         1.0       537.0        537.0           Cash       Regular     April
# ..        ...         ...          ...            ...           ...       ...
# 495       2.0       310.0        620.0           Card        Member       May
# 496       2.0       834.0       1668.0         Online       Regular  February
# 497       6.0       512.0       3072.0           Card        Member      June
# 498       6.0       537.0       3222.0           Cash       Regular      June
# 499       1.0       970.0        970.0         Online       Regular       May
#
# [500 rows x 12 columns]

# %% [markdown]
# ## Extract "year" from "Date"

# %%
df['year']= df["Date"].dt.year

# %%
df
# Out:
#      Transaction_ID       Date    Store       City  Product category  \
# 0              1141 2024-05-01   Imtiaz  Islamabad  Chicken     Meat
# 1              1399 2024-11-04   Imtiaz  Islamabad      Oil   Grains
# 2              1007 2024-12-04   Imtiaz  Islamabad      Oil   Grains
# 3              1335 2024-04-02   Imtiaz  Islamabad  Chicken     Meat
# 4              1323 2024-04-02    Metro  Islamabad     Milk    Dairy
# ..              ...        ...      ...        ...      ...      ...
# 495            1072 2024-05-07   Imtiaz     Lahore     Rice   Grains
# 496            1107 2024-02-04  Alfatah    Karachi    Apple   Fruits
# 497            1271 2024-06-10   Imtiaz    Karachi     Rice   Grains
# 498            1436 2024-06-05   Imtiaz     Lahore    Apple   Fruits
# 499            1103 2024-05-08  Alfatah    Karachi      Oil   Grains
#
#      Quantity  Unit_Price  Total_Price Payment_Method Customer_Type     Month  \
# 0         1.0       537.0        537.0         Online        Member       May
# 1         5.0       537.0       2685.0         Online       Regular  November
# 2         4.0       785.0       3140.0           Card       Regular  December
# 3         1.0       848.0        848.0           Cash       Regular     April
# 4         1.0       537.0        537.0           Cash       Regular     April
# ..        ...         ...          ...            ...           ...       ...
# 495       2.0       310.0        620.0           Card        Member       May
# 496       2.0       834.0       1668.0         Online       Regular  February
# 497       6.0       512.0       3072.0           Card        Member      June
# 498       6.0       537.0       3222.0           Cash       Regular      June
# 499       1.0       970.0        970.0         Online       Regular       May
#
#      year
# 0    2024
# 1    2024
# 2    2024
# 3    2024
# 4    2024
# ..    ...
# 495  2024
# 496  2024
# 497  2024
# 498  2024
# 499  2024
#
# [500 rows x 13 columns]

# %%
df['year'].unique()
# Out:
# array([2024], dtype=int32)

# %% [markdown]
#   # To calculate Sales by Month, use groupby()

# %%
sales_by_month = df.groupby('Month')['Total_Price'].sum().sort_values(ascending=False)

# %%
sales_by_month
# Out:
# Month
# April        217320.0
# January      179379.0
# March        158937.0
# February     147995.0
# May          128448.0
# June         116715.0
# September     40774.0
# December      28451.0
# July          21687.0
# October       21512.0
# August        14572.0
# November      12135.0
# Name: Total_Price, dtype: float64

# %% [markdown]
# # to calculate sales by store and Total_Price using groupby()

# %%
sales_by_store = df.groupby("Store")['Total_Price'].sum().sort_values(ascending =False)

# %%
sales_by_store
# Out:
# Store
# Alfatah    369784.0
# Metro      363914.0
# Imtiaz     354227.0
# Name: Total_Price, dtype: float64

# %%
sales_by_product = df.groupby(["Month","Store","Product"])['Total_Price'].sum().sort_values(ascending=False)

# %%
sales_by_product
# Out:
# Month      Store    Product
# January    Alfatah  Rice       21396.0
#            Imtiaz   Apple      17974.0
# April      Alfatah  Sugar      17643.0
# March      Metro    Sugar      17464.0
# April      Metro    Rice       17194.0
#                                 ...
# July       Imtiaz   Sugar        504.0
# October    Metro    Apple        475.0
# February   Imtiaz   Oil          456.0
# October    Imtiaz   Milk         378.0
# September  Alfatah  Bread        375.0
# Name: Total_Price, Length: 184, dtype: float64

# %%
store_summary = df.groupby('Store')['Total_Price'].agg( Total='sum', Average='mean', Maximum='max', Minimum='min', Transactions='count')

# %%
store_summary
# Out:
#             Total      Average  Maximum  Minimum  Transactions
# Store
# Alfatah  369784.0  2254.780488   8910.0     78.0           164
# Imtiaz   354227.0  2035.787356   9440.0    124.0           174
# Metro    363914.0  2246.382716   8800.0     62.0           162

# %%
pivot = df.pivot_table( index='Month', columns='Store', values='Total_Price', aggfunc='sum')
pivot.plot(kind='bar', figsize=(10,5), width=0.9, color=['gold','blue','orange'])
plt.title('Monthly Sales by Store', fontweight= 'bold')
plt.xlabel('Month', fontweight= "bold")
plt.ylabel('Total Sales', fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,x='Month',y='Total_Price',hue='Store')

plt.title('Monthly Sales by Store', fontsize=16, fontweight='bold')
plt.xlabel('Month', fontsize=12, fontweight='bold')
plt.ylabel('Total Sales', fontsize=12, fontweight='bold')

plt.xticks(rotation=45)
plt.show()

# %%
sales_by_product = (df.groupby(['Month','Store'])['Total_Price'].sum())
sales_by_product
# Out:
# Month      Store
# April      Alfatah    75139.0
#            Imtiaz     68299.0
#            Metro      73882.0
# August     Alfatah     5772.0
#            Metro       8800.0
# December   Alfatah    15979.0
#            Imtiaz      7088.0
#            Metro       5384.0
# February   Alfatah    64502.0
#            Imtiaz     47547.0
#            Metro      35946.0
# January    Alfatah    73006.0
#            Imtiaz     50507.0
#            Metro      55866.0
# July       Alfatah     4286.0
#            Imtiaz      9639.0
#            Metro       7762.0
# June       Alfatah    45889.0
#            Imtiaz     31694.0
#            Metro      39132.0
# March      Alfatah    42880.0
#            Imtiaz     55054.0
#            Metro      61003.0
# May        Alfatah    31454.0
#            Imtiaz     52692.0
#            Metro      44302.0
# November   Alfatah     3896.0
#            Imtiaz      5153.0
#            Metro       3086.0
# October    Alfatah     3840.0
#            Imtiaz      4422.0
#            Metro      13250.0
# September  Alfatah     3141.0
#            Imtiaz     22132.0
#            Metro      15501.0
# Name: Total_Price, dtype: float64

# %%
sales_by_product
# Out:
# Month      Store
# April      Alfatah    75139.0
#            Imtiaz     68299.0
#            Metro      73882.0
# August     Alfatah     5772.0
#            Metro       8800.0
# December   Alfatah    15979.0
#            Imtiaz      7088.0
#            Metro       5384.0
# February   Alfatah    64502.0
#            Imtiaz     47547.0
#            Metro      35946.0
# January    Alfatah    73006.0
#            Imtiaz     50507.0
#            Metro      55866.0
# July       Alfatah     4286.0
#            Imtiaz      9639.0
#            Metro       7762.0
# June       Alfatah    45889.0
#            Imtiaz     31694.0
#            Metro      39132.0
# March      Alfatah    42880.0
#            Imtiaz     55054.0
#            Metro      61003.0
# May        Alfatah    31454.0
#            Imtiaz     52692.0
#            Metro      44302.0
# November   Alfatah     3896.0
#            Imtiaz      5153.0
#            Metro       3086.0
# October    Alfatah     3840.0
#            Imtiaz      4422.0
#            Metro      13250.0
# September  Alfatah     3141.0
#            Imtiaz     22132.0
#            Metro      15501.0
# Name: Total_Price, dtype: float64

# %%
df
# Out:
#      Transaction_ID       Date    Store       City  Product category  \
# 0              1141 2024-05-01   Imtiaz  Islamabad  Chicken     Meat
# 1              1399 2024-11-04   Imtiaz  Islamabad      Oil   Grains
# 2              1007 2024-12-04   Imtiaz  Islamabad      Oil   Grains
# 3              1335 2024-04-02   Imtiaz  Islamabad  Chicken     Meat
# 4              1323 2024-04-02    Metro  Islamabad     Milk    Dairy
# ..              ...        ...      ...        ...      ...      ...
# 495            1072 2024-05-07   Imtiaz     Lahore     Rice   Grains
# 496            1107 2024-02-04  Alfatah    Karachi    Apple   Fruits
# 497            1271 2024-06-10   Imtiaz    Karachi     Rice   Grains
# 498            1436 2024-06-05   Imtiaz     Lahore    Apple   Fruits
# 499            1103 2024-05-08  Alfatah    Karachi      Oil   Grains
#
#      Quantity  Unit_Price  Total_Price Payment_Method Customer_Type     Month  \
# 0         1.0       537.0        537.0         Online        Member       May
# 1         5.0       537.0       2685.0         Online       Regular  November
# 2         4.0       785.0       3140.0           Card       Regular  December
# 3         1.0       848.0        848.0           Cash       Regular     April
# 4         1.0       537.0        537.0           Cash       Regular     April
# ..        ...         ...          ...            ...           ...       ...
# 495       2.0       310.0        620.0           Card        Member       May
# 496       2.0       834.0       1668.0         Online       Regular  February
# 497       6.0       512.0       3072.0           Card        Member      June
# 498       6.0       537.0       3222.0           Cash       Regular      June
# 499       1.0       970.0        970.0         Online       Regular       May
#
#      year
# 0    2024
# 1    2024
# 2    2024
# 3    2024
# 4    2024
# ..    ...
# 495  2024
# 496  2024
# 497  2024
# 498  2024
# 499  2024
#
# [500 rows x 13 columns]

# %%
payment_sales = df.groupby('Payment_Method')['Total_Price'].sum()

# %%
plt.pie(payment_sales, labels=payment_sales.index,autopct='%1.1f%%', explode=[0.02,0.05,0.02], shadow= True)
plt.title("Sales distribution by payment method", fontweight='bold', fontsize=16)
plt.show()
